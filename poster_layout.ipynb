# %%
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np

# path to the rcParams script
import sys
sys.path.append(r"C:\Users\jlubbers\OneDrive - DOI\Research\Coding\Python_scripts")
import mpl_defaults

# %%
# Here's the overall layout
fig = plt.figure(figsize=(48, 36))
gspec = gridspec.GridSpec(
    ncols=12,
    nrows=10,
    figure=fig,
    height_ratios=np.full(10, 0.1),
    width_ratios=np.full(12, 1 / 12),
    wspace=0.4,
    hspace=0.4,
)
# title and authors
ax_title = plt.subplot(
    gspec[0, 2:10], frameon=True, xlim=[0, 1], xticks=[], ylim=[0, 1], yticks=[]
)
# left logos
ax_title_left_left = plt.subplot(gspec[0, 0], frameon=True, xticks=[], yticks=[])
ax_title_left = plt.subplot(gspec[0, 1], frameon=True, xticks=[], yticks=[])

# one big right logo
ax_title_right = plt.subplot(gspec[0, 10:], frameon=True, xticks=[], yticks=[])


# upper left axis
ax_ul = plt.subplot(
    gspec[1:5, :4], frameon=True, xlim=[0, 1], xticks=[], ylim=[0, 1], yticks=[]
)
# lower left axis
ax_ll = plt.subplot(gspec[5:10, :4], frameon=True, xticks=[], yticks=[])
# ax_ll_caption = plt.subplot(gspec[5, :4], frameon=False, xticks=[], yticks=[])

# upper middle caption/ title text
ax_um_caption = plt.subplot(
    gspec[1, 4:8], frameon=True, xlim=[0, 1], xticks=[], ylim=[0, 1], yticks=[]
)
# upper middle top left
ax_umtl = plt.subplot(gspec[2:4, 4:6])
# upper middle top right
ax_umtr = plt.subplot(gspec[2:4, 6:8])
# upper middle lower left
ax_umll = plt.subplot(gspec[4:6, 4:6])
# upper middle lower right
ax_umlr = plt.subplot(gspec[4:6, 6:8])

# lower middle caption/title
ax_lm_caption = plt.subplot(
    gspec[6, 4:8], frameon=True, xlim=[0, 1], xticks=[], ylim=[0, 1], yticks=[]
)

# lower middle
ax_lm = plt.subplot(gspec[7:, 4:8], frameon=True,)


# upper right caption/ title text
ax_ur_caption = plt.subplot(
    gspec[1, 8:], frameon=True, xlim=[0, 1], xticks=[], ylim=[0, 1], yticks=[]
)
# upper right top left
ax_urtl = plt.subplot(gspec[2:4, 8:10])
# upper right top right
ax_urtr = plt.subplot(gspec[2:4, 10:])
# upper right lower left
ax_urll = plt.subplot(gspec[4:6, 8:10])
# upper right lower right
ax_urlr = plt.subplot(gspec[4:6, 10:])

# bottom right
ax_lr = plt.subplot(
    gspec[6:8, 8:], frameon=True, xlim=[0, 1], xticks=[], ylim=[0, 1], yticks=[]
)
# conclusions
ax_conc = plt.subplot(
    gspec[8:, 8:], frameon=True, xlim=[0, 1], xticks=[], ylim=[0, 1], yticks=[]
)
